# %% [markdown]
# <a href="https://colab.research.google.com/github/OrianaMart/ECEN-403---Team-39/blob/ML/image_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bing_image_downloader import downloader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.9/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.9/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
# ...

# %%
dir = '/content/Images'

# %%
downloader.download("TI-Nspire CX CAS", limit = 500, output_dir = dir, adult_filter_off = True)
# Out:
# [%] Downloading Images to /content/Images/TI-Nspire CX CAS
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.schoolmart.com/wp-content/uploads/2016/04/ti-nspcxii-cas.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://mathclasscalculator.com/wp-content/uploads/2017/07/nsire-cx-cas.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://thecraftycanvas.com/library/files/2012/09/0.TI-Nspire_cx_cas.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://s3.amazonaws.com/magoosh-company-site/wp-content/uploads/sites/13/2017/03/12165327/TI-nspire_CX_CAS-516x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.cemetech.net/media/news_attachment/916/nspirecxcasii2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://technabob.com/blog/wp-content/uploads/2012/03/ti-nspire-cx-cas.jpg
# [%] File Downloaded !
#
# ...

# %%
import os
import cv2
import imghdr

def check_images( s_dir, ext_list):
    bad_images=[]
    bad_ext=[]
    s_list= os.listdir(s_dir)
    for klass in s_list:
        klass_path=os.path.join (s_dir, klass)
        print ('processing class directory ', klass)
        if os.path.isdir(klass_path):
            file_list=os.listdir(klass_path)
            for f in file_list:               
                f_path=os.path.join (klass_path,f)
                tip = imghdr.what(f_path)
                if ext_list.count(tip) == 0:
                  bad_images.append(f_path)
                if os.path.isfile(f_path):
                    try:
                        img=cv2.imread(f_path)
                        shape=img.shape
                    except:
                        print('file ', f_path, ' is not a valid image file')
                        bad_images.append(f_path)
                else:
                    print('*** fatal error, you a sub directory ', f, ' in class directory ', klass)
        else:
            print ('*** WARNING*** you have files in ', s_dir, ' it should only contain sub directories')
    return bad_images, bad_ext

source_dir =r'/content/Images'
good_exts=['jpg', 'png', 'jpeg', 'gif', 'bmp' ] # list of acceptable extensions
bad_file_list, bad_ext_list=check_images(source_dir, good_exts)
if len(bad_file_list) !=0:
    print('improper image files are listed below')
    for i in range (len(bad_file_list)):
        print (bad_file_list[i])
else:
    print(' no improper image files were found')
# Out:
# processing class directory  TI-84 Plus CE
# processing class directory  TI-73 Explorer
# file  /content/Images/TI-73 Explorer/Image_49.gif  is not a valid image file
# file  /content/Images/TI-73 Explorer/Image_167.jpg  is not a valid image file
# file  /content/Images/TI-73 Explorer/Image_137.gif  is not a valid image file
# file  /content/Images/TI-73 Explorer/Image_119.jpg  is not a valid image file
# file  /content/Images/TI-73 Explorer/Image_55.gif  is not a valid image file
# file  /content/Images/TI-73 Explorer/Image_134.gif  is not a valid image file
# file  /content/Images/TI-73 Explorer/Image_116.jpg  is not a valid image file
# file  /content/Images/TI-73 Explorer/Image_169.jpg  is not a valid image file
# file  /content/Images/TI-73 Explorer/Image_16.gif  is not a valid image file
# file  /content/Images/TI-73 Explorer/Image_167.gif  is not a valid image file
# processing class directory  TI-Nspire CX II
# ...

# %%
# !zip -r /content/Calculator.zip /content/Images
# Out:
#   adding: content/Images/ (stored 0%)
#   adding: content/Images/TI-84 Plus CE/ (stored 0%)
#   adding: content/Images/TI-84 Plus CE/Image_76.png (stored 0%)
#   adding: content/Images/TI-84 Plus CE/Image_126.JPG (deflated 1%)
#   adding: content/Images/TI-84 Plus CE/Image_57.jpg (deflated 0%)
#   adding: content/Images/TI-84 Plus CE/Image_164.png (deflated 0%)
#   adding: content/Images/TI-84 Plus CE/Image_61.jpg (deflated 1%)
#   adding: content/Images/TI-84 Plus CE/Image_22.jpg (deflated 4%)
#   adding: content/Images/TI-84 Plus CE/Image_58.jpg (deflated 1%)
#   adding: content/Images/TI-84 Plus CE/Image_105.jpg (deflated 2%)
#   adding: content/Images/TI-84 Plus CE/Image_11.jpg (deflated 0%)
#   adding: content/Images/TI-84 Plus CE/Image_107.JPG (deflated 2%)
#   adding: content/Images/TI-84 Plus CE/Image_81.jpg (deflated 0%)
#   adding: content/Images/TI-84 Plus CE/Image_73.jpg (deflated 1%)
#   adding: content/Images/TI-84 Plus CE/Image_15.jpg (deflated 0%)
# ...

# %%
from google.colab import files
files.download("/content/Calculator.zip")

# %%
# %rm -rf NXP Tower System/ #This is only to be run when the file needs to be cleared out
